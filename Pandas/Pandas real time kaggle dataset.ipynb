# %%
import numpy as np
import pandas as pd

# %%
air_quality_dataset = pd.read_csv("globalAirQuality.csv")
#print(air_quality_dataset.head())
print(air_quality_dataset.columns)
#print(air_quality_dataset.describe())
# Out:
# Index(['timestamp', 'country', 'city', 'latitude', 'longitude', 'pm25', 'pm10',
#        'no2', 'so2', 'o3', 'co', 'aqi', 'temperature', 'humidity',
#        'wind_speed'],
#       dtype='str')
